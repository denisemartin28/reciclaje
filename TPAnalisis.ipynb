# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
reciclaje = pd.read_csv(r'C:\Users\DeMartinCal\Desktop\reciclaje\reciclaje-master 6 de nov\reciclaje-master\pesajes_nulos.csv', delimiter=';')

# %%
reciclaje.head(4)
# Out:
#                PUNTO    COMUNA  ANIO  MES  SEMANA  VIDRIO  PAPEL_Y_CARTON  \
# 0  PARQUE AVELLANEDA  COMUNA 9  2015    1       1  163.23          123.67
# 1  PARQUE AVELLANEDA  COMUNA 9  2015    1       2  143.71          138.21
# 2  PARQUE AVELLANEDA  COMUNA 9  2015    1       3  134.47          154.43
# 3  PARQUE AVELLANEDA  COMUNA 9  2015    1       4  124.14          205.54
#
#    METAL  TELGOPOR  PLASTICOS_TODOS_LOS_DEMAS  TETRA_BRICK
# 0  27.55      0.00                      67.17         8.54
# 1   7.91      0.00                      67.31         8.54
# 2   7.24      1.42                      75.35         8.54
# 3  13.44      4.65                      69.74         8.54

# %%
print("El dataset de reciclaje está compuesto por "+ str(np.shape(reciclaje)[0]) + " filas y " + str(np.shape(reciclaje)[1]) + " columnas")
# Out:
# El dataset de reciclaje está compuesto por 2521 filas y 11 columnas

# %%
reciclaje['TOTAL']= reciclaje['VIDRIO'] + reciclaje['PAPEL_Y_CARTON'] + reciclaje['METAL'] + reciclaje['TELGOPOR'] + reciclaje['TETRA_BRICK'] + reciclaje['PLASTICOS_TODOS_LOS_DEMAS'] 
reciclaje.head(5)
# Out:
#                PUNTO    COMUNA  ANIO  MES  SEMANA  VIDRIO  PAPEL_Y_CARTON  \
# 0  PARQUE AVELLANEDA  COMUNA 9  2015    1       1  163.23          123.67
# 1  PARQUE AVELLANEDA  COMUNA 9  2015    1       2  143.71          138.21
# 2  PARQUE AVELLANEDA  COMUNA 9  2015    1       3  134.47          154.43
# 3  PARQUE AVELLANEDA  COMUNA 9  2015    1       4  124.14          205.54
# 4  PARQUE AVELLANEDA  COMUNA 9  2015    1       5  104.16          111.43
#
#    METAL  TELGOPOR  PLASTICOS_TODOS_LOS_DEMAS  TETRA_BRICK   TOTAL
# 0  27.55      0.00                      67.17         8.54  390.16
# 1   7.91      0.00                      67.31         8.54  365.68
# 2   7.24      1.42                      75.35         8.54  381.45
# 3  13.44      4.65                      69.74         8.54  426.05
# 4   8.50      0.78                      64.36         8.54  297.77

# %% [markdown]
# # Total de kilogramos por mes y comuna

# %%
kg_totales_punto=pd.pivot_table(reciclaje, values='TOTAL', index='MES', columns='COMUNA', aggfunc=np.sum)
kg_totales_punto
# Out:
# COMUNA   COMUNA 1  COMUNA 10  COMUNA 11   COMUNA 12  COMUNA 13  COMUNA 14  \
# MES
# 1       7029.2640  22006.279  24649.748  20888.7200  11888.777  5201.1900
# 2       6362.4750  19393.290  16708.988  20673.8430  10254.510  4226.4960
# 3       6570.8380  22391.713  21760.514  18719.9102  11347.637  5068.3040
# 4       7624.8250  26835.059  25118.415  21394.8460  14456.639  6451.7070
# 5       5564.3260  16157.694  19809.346  20004.0810  11165.294  5774.3220
# 6       5969.1721  20727.723  20833.726  19232.9410  11774.947  6613.5260
# 7       9394.0180  24877.543  30197.637  21931.0550  15273.560  7280.9750
# 8       8703.2460  24687.528  33535.188  22043.1838  15849.252  6996.8380
# 9       8786.0130  24815.576  36209.153  19745.3690  14714.187  6299.7290
# 10      3811.3380   9648.233  12586.870   6665.4170   7332.598  2543.6730
# 11      3602.5450  10117.721  12486.990   6868.7490   6007.561  2605.3340
# 12      5347.5770  16306.596  17213.756   9747.6630   9729.070  3838.5401
#
# ...

# %%
chart = sns.barplot(x='COMUNA', y='TOTAL', hue='ANIO', data=reciclaje, palette=("Greens_r"))
plt.title('Kg por comuna')
plt.gcf().set_size_inches(9, 8.27)
chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=50, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='xx-large',


)
# Out:
# [Text(0, 0, 'COMUNA 9'),
#  Text(0, 0, 'COMUNA 6'),
#  Text(0, 0, 'COMUNA 7'),
#  Text(0, 0, 'COMUNA 15'),
#  Text(0, 0, 'COMUNA 4'),
#  Text(0, 0, 'COMUNA 12'),
#  Text(0, 0, 'COMUNA 3'),
#  Text(0, 0, 'COMUNA 11'),
#  Text(0, 0, 'COMUNA 5'),
#  Text(0, 0, 'COMUNA 13'),
#  Text(0, 0, 'COMUNA 10'),
#  Text(0, 0, 'COMUNA 14'),
#  Text(0, 0, 'COMUNA 2'),
#  Text(0, 0, 'COMUNA 8'),
#  Text(0, 0, 'COMUNA 1')]

# %% [markdown]
# ### Se evidencia que durante 2016 se recolectaron más reciclables en la comuna 11 y la que menos juntó fue la comuna 8

# %% [markdown]
# # Estadísticas descriptivas

# %%
reciclaje.describe().iloc[:,3:10]
# Out:
#             VIDRIO  PAPEL_Y_CARTON        METAL     TELGOPOR  \
# count  2521.000000     2521.000000  2521.000000  2521.000000
# mean    241.801023      327.833270    21.668569     3.670588
# std     178.868752      232.606265    40.033340    13.501451
# min       0.000000        9.850000     0.000000     0.000000
# 25%     113.971000      170.120000     8.880000     0.000000
# 50%     208.610000      285.213000    18.300000     1.830000
# 75%     324.017000      425.418000    28.889000     3.960000
# max    1168.740000     1649.610000  1665.170000   338.910000
#
#        PLASTICOS_TODOS_LOS_DEMAS  TETRA_BRICK        TOTAL
# count                2521.000000  2521.000000  2521.000000
# mean                  139.681113     9.778578   744.433142
# std                    91.770326    12.315871   504.438929
# min                     0.000000     0.000000    24.690000
# 25%                    68.220000     3.682000   384.980000
# 50%                   126.969000     7.999000   660.334000
# ...

# %%
pesajes_totalMensual =reciclaje.iloc[:,[1,2,3,5,6,7,8,9,10,11]].groupby(["ANIO","MES"], as_index=False).sum()
pesajes_totalMensual
# Out:
#     ANIO  MES     VIDRIO  PAPEL_Y_CARTON      METAL  TELGOPOR  \
# 0   2015    1  27410.250      35016.8000  2467.1600   540.051
# 1   2015    2  20594.788      27481.6990  1348.6020   223.156
# 2   2015    3  22267.080      31354.5200  1929.2700   354.461
# 3   2015    4  25367.073      34547.3300  2103.6290   489.991
# 4   2015    5  21481.038      32630.8440  1857.3340   297.879
# 5   2015    6  20551.076      28293.0650  1579.5381   389.093
# 6   2015    7  25001.783      36302.1220  2007.3610   260.177
# 7   2015    8  31397.065      45662.1558  2489.2700   327.933
# 8   2015    9  27758.229      39068.0190  2339.3660   377.736
# 9   2015   10  26288.656      36550.6290  2244.1070   281.040
# 10  2015   11  25933.238      35298.9620  2329.2550   271.145
# 11  2015   12  40802.660      50138.4481  3448.6400   524.253
# 12  2016    1  31252.337      41626.0760  5180.7920   386.026
# 13  2016    2  26245.363      37304.2943  2510.3210   355.715
# ...

# %%
anio2015=pesajes_totalMensual.loc[pesajes_totalMensual['ANIO'] == 2015]
anio2016=pesajes_totalMensual.loc[pesajes_totalMensual['ANIO'] == 2016]
anio2015
# Out:
#     ANIO  MES     VIDRIO  PAPEL_Y_CARTON      METAL  TELGOPOR  \
# 0   2015    1  27410.250      35016.8000  2467.1600   540.051
# 1   2015    2  20594.788      27481.6990  1348.6020   223.156
# 2   2015    3  22267.080      31354.5200  1929.2700   354.461
# 3   2015    4  25367.073      34547.3300  2103.6290   489.991
# 4   2015    5  21481.038      32630.8440  1857.3340   297.879
# 5   2015    6  20551.076      28293.0650  1579.5381   389.093
# 6   2015    7  25001.783      36302.1220  2007.3610   260.177
# 7   2015    8  31397.065      45662.1558  2489.2700   327.933
# 8   2015    9  27758.229      39068.0190  2339.3660   377.736
# 9   2015   10  26288.656      36550.6290  2244.1070   281.040
# 10  2015   11  25933.238      35298.9620  2329.2550   271.145
# 11  2015   12  40802.660      50138.4481  3448.6400   524.253
#
#     PLASTICOS_TODOS_LOS_DEMAS  TETRA_BRICK        TOTAL
# 0                  14586.9400     1385.710   81406.9110
# ...

# %%
plt.figure(figsize=(8,8))
plt.plot(anio2015['MES'], anio2015['VIDRIO'], label='VIDRIO');
plt.plot(anio2015['MES'], anio2015['PAPEL_Y_CARTON'], label='PAPEL_Y_CARTON');
plt.plot(anio2015['MES'], anio2015['METAL'], label='METAL');
plt.plot(anio2015['MES'], anio2015['TELGOPOR'], label='TELGOPOR');
plt.plot(anio2015['MES'], anio2015['PLASTICOS_TODOS_LOS_DEMAS'], label='PLASTICOS_TODOS_LOS_DEMAS');
plt.plot(anio2015['MES'], anio2015['TETRA_BRICK'], label='TETRA_BRICK');
plt.legend(loc='upper left')
plt.title('Evolución del reciclaje 2015')
plt.ylabel('Cantidad de kilos')
plt.xlabel('Mes')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.plot(anio2016['MES'], anio2016['VIDRIO'], label='VIDRIO');
plt.plot(anio2016['MES'], anio2016['PAPEL_Y_CARTON'], label='PAPEL_Y_CARTON');
plt.plot(anio2016['MES'], anio2016['METAL'], label='METAL');
plt.plot(anio2016['MES'], anio2016['TELGOPOR'], label='TELGOPOR');
plt.plot(anio2016['MES'], anio2016['PLASTICOS_TODOS_LOS_DEMAS'], label='PLASTICOS_TODOS_LOS_DEMAS');
plt.plot(anio2016['MES'], anio2016['TETRA_BRICK'], label='TETRA_BRICK');
plt.legend(loc='upper left')
plt.title('Evolución del reciclaje 2016')
plt.ylabel('Cantidad de kilos')
plt.xlabel('Mes')
plt.show()

# %% [markdown]
# ### Matriz de correlación

# %%
features=reciclaje.iloc[:,5:12]
import seaborn as sns 

f, ax = plt.subplots(figsize=(10, 8)) 
corr = features.corr() 
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True), 
      square=True, ax=ax)

# %%
 df=({'x' : anio2015['MES'], 'y1': anio2015['VIDRIO'], 'y2': anio2015['PAPEL_Y_CARTON'], 'y3': anio2015['METAL'], 'y4': anio2015['TELGOPOR'],'y5': anio2015['PLASTICOS_TODOS_LOS_DEMAS'], 'y6': anio2015['TETRA_BRICK]})
