# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
reciclaje = pd.read_csv(r'C:\Users\DeMartinCal\Desktop\reciclaje\reciclaje-master\pesajes_nulos.csv', delimiter=';')

# %%
reciclaje.head(4)
# Out:
#   PUNTO COMUNA  ANIO   MES  SEMANA  VIDRIO PAPEL_Y_CARTON  METAL  TELGOPOR  \
# 0  8.54   8.54  8.54  8.54    8.54    8.54           8.54   8.54      8.54
# 1  8.54   8.54  8.54  8.54    8.54    8.54           8.54   8.54      8.54
# 2  8.54   8.54  8.54  8.54    8.54    8.54           8.54   8.54      8.54
# 3  8.54   8.54  8.54  8.54    8.54    8.54           8.54   8.54      8.54
#
#    PLASTICOS_TODOS_LOS_DEMAS  TETRA_BRICK
# 0                       8.54         8.54
# 1                       8.54         8.54
# 2                       8.54         8.54
# 3                       8.54         8.54

# %%
print("El dataset de reciclaje está compuesto por "+ str(np.shape(reciclaje)[0]) + " filas y " + str(np.shape(reciclaje)[1]) + " columnas")
# Out:
# El dataset de reciclaje está compuesto por 2521 filas y 11 columnas

# %%
reciclaje['TOTAL']= reciclaje['VIDRIO'] + reciclaje['METAL'] + reciclaje['TELGOPOR'] + reciclaje['TETRA_BRICK'] + reciclaje['PLASTICOS_TODOS_LOS_DEMAS'] 
reciclaje
# Out:
#                              PUNTO     COMUNA     ANIO    MES  SEMANA  \
# 0                             8.54       8.54     8.54   8.54    8.54
# 1                             8.54       8.54     8.54   8.54    8.54
# 2                             8.54       8.54     8.54   8.54    8.54
# 3                             8.54       8.54     8.54   8.54    8.54
# 4                             8.54       8.54     8.54   8.54    8.54
# 5                PARQUE CENTENARIO   COMUNA 6  2015.00   1.00    1.00
# 6                PARQUE CENTENARIO   COMUNA 6  2015.00   1.00    2.00
# 7                PARQUE CENTENARIO   COMUNA 6  2015.00   1.00    3.00
# 8                PARQUE CENTENARIO   COMUNA 6  2015.00   1.00    4.00
# 9                PARQUE CENTENARIO   COMUNA 6  2015.00   1.00    5.00
# 10                           13.62      13.62    13.62  13.62   13.62
# 11                           13.62      13.62    13.62  13.62   13.62
# ...

# %%
kg_totales_punto=pd.pivot_table(reciclaje, values='TOTAL', index='ANIO', columns='PUNTO', aggfunc=np.sum)
kg_totales_punto
# Out:
# PUNTO     0.3  0.6   0.79   1.25  1.29    1.79  1.88  10.78  12.14   12.17  \
# ANIO
# 0.30     19.5  NaN    NaN    NaN   NaN     NaN   NaN    NaN    NaN     NaN
# 0.60      NaN  3.0    NaN    NaN   NaN     NaN   NaN    NaN    NaN     NaN
# 0.79      NaN  NaN  51.35    NaN   NaN     NaN   NaN    NaN    NaN     NaN
# 1.25      NaN  NaN    NaN  81.25   NaN     NaN   NaN    NaN    NaN     NaN
# 1.29      NaN  NaN    NaN    NaN  6.45     NaN   NaN    NaN    NaN     NaN
# 1.79      NaN  NaN    NaN    NaN   NaN  116.35   NaN    NaN    NaN     NaN
# 1.88      NaN  NaN    NaN    NaN   NaN     NaN   9.4    NaN    NaN     NaN
# 2.08      NaN  NaN    NaN    NaN   NaN     NaN   NaN    NaN    NaN     NaN
# 2.31      NaN  NaN    NaN    NaN   NaN     NaN   NaN    NaN    NaN     NaN
# 2.47      NaN  NaN    NaN    NaN   NaN     NaN   NaN    NaN    NaN     NaN
# 2.87      NaN  NaN    NaN    NaN   NaN     NaN   NaN    NaN    NaN     NaN
# ...

# %%
export_csv = kg_totales_punto.to_csv (r'kg_totales_punto.csv', index = None, header=True, sep=';')
