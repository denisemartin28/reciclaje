# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
reciclaje = pd.read_csv(r'C:\Users\DeMartinCal\Desktop\reciclaje\reciclaje-master 6 de nov\reciclaje-master\pesajes_nulos.csv', delimiter=';')

# %%
reciclaje.head(4)
# Out:
#                PUNTO    COMUNA  ANIO  MES  SEMANA  VIDRIO  PAPEL_Y_CARTON  \
# 0  PARQUE AVELLANEDA  COMUNA 9  2015    1       1  163.23          123.67
# 1  PARQUE AVELLANEDA  COMUNA 9  2015    1       2  143.71          138.21
# 2  PARQUE AVELLANEDA  COMUNA 9  2015    1       3  134.47          154.43
# 3  PARQUE AVELLANEDA  COMUNA 9  2015    1       4  124.14          205.54
#
#    METAL  TELGOPOR  PLASTICOS_TODOS_LOS_DEMAS  TETRA_BRICK
# 0  27.55      0.00                      67.17         8.54
# 1   7.91      0.00                      67.31         8.54
# 2   7.24      1.42                      75.35         8.54
# 3  13.44      4.65                      69.74         8.54

# %%
print("El dataset de reciclaje está compuesto por "+ str(np.shape(reciclaje)[0]) + " filas y " + str(np.shape(reciclaje)[1]) + " columnas")
# Out:
# El dataset de reciclaje está compuesto por 2521 filas y 11 columnas

# %%
reciclaje['TOTAL']= reciclaje['VIDRIO'] + reciclaje['PAPEL_Y_CARTON'] + reciclaje['METAL'] + reciclaje['TELGOPOR'] + reciclaje['TETRA_BRICK'] + reciclaje['PLASTICOS_TODOS_LOS_DEMAS'] 
reciclaje
# Out:
#                              PUNTO     COMUNA  ANIO  MES  SEMANA   VIDRIO  \
# 0                PARQUE AVELLANEDA   COMUNA 9  2015    1       1  163.230
# 1                PARQUE AVELLANEDA   COMUNA 9  2015    1       2  143.710
# 2                PARQUE AVELLANEDA   COMUNA 9  2015    1       3  134.470
# 3                PARQUE AVELLANEDA   COMUNA 9  2015    1       4  124.140
# 4                PARQUE AVELLANEDA   COMUNA 9  2015    1       5  104.160
# 5                PARQUE CENTENARIO   COMUNA 6  2015    1       1  341.870
# 6                PARQUE CENTENARIO   COMUNA 6  2015    1       2  262.150
# 7                PARQUE CENTENARIO   COMUNA 6  2015    1       3  254.820
# 8                PARQUE CENTENARIO   COMUNA 6  2015    1       4  156.540
# 9                PARQUE CENTENARIO   COMUNA 6  2015    1       5  544.170
# 10                PARQUE CHACABUCO   COMUNA 7  2015    1       1  164.600
# 11                PARQUE CHACABUCO   COMUNA 7  2015    1       2  158.030
# ...

# %%
kg_totales_punto=pd.pivot_table(reciclaje, values='TOTAL', index='ANIO', columns='PUNTO', aggfunc=np.sum)
kg_totales_punto
# Out:
# PUNTO  PARQUE AVELLANEDA  PARQUE CENTENARIO  PARQUE CHACABUCO  \
# ANIO
# 2015          23336.4330          49010.920         38921.252
# 2016          22408.8703          53743.795         41131.225
#
# PUNTO  PARQUE LOS ANDES  PARQUE PATRICIOS  PARQUE RIVADAVIA  PARQUE SAAVEDRA  \
# ANIO
# 2015          24568.046         27824.931         42982.634       56188.1068
# 2016          20017.192         15008.465         32610.553       70316.9242
#
# PUNTO  PLAZA 1RO DE MAYO  PLAZA A DEL VALLE  PLAZA ALEM  ...  \
# ANIO                                                     ...
# 2015           35035.127          58661.003   41818.082  ...
# 2016           27407.856          49285.601   39592.665  ...
#
# PUNTO  PLAZA M BELGRANO  PLAZA M DE ANDREA  PLAZA PALERMO VIEJO  \
# ANIO
# 2015          22658.302          30038.816            9101.1721
# 2016          19519.480          20618.113            6993.5480
#
# PUNTO  PLAZA PUEYRREDON  PLAZA SANTOJANNI  PLAZA SUDAMERICANA  \
# ANIO
# ...

# %%
chart = sns.barplot(x='PUNTO', y='TOTAL', hue='ANIO', data=reciclaje, palette=("Greens_r"))
plt.gcf().set_size_inches(20, 8.27)
chart.set_xticklabels(
    chart.get_xticklabels(), 
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'

)
# Out:
# [Text(0, 0, 'PARQUE AVELLANEDA'),
#  Text(0, 0, 'PARQUE CENTENARIO'),
#  Text(0, 0, 'PARQUE CHACABUCO'),
#  Text(0, 0, 'PARQUE LOS ANDES'),
#  Text(0, 0, 'PARQUE PATRICIOS'),
#  Text(0, 0, 'PARQUE RIVADAVIA'),
#  Text(0, 0, 'PARQUE SAAVEDRA'),
#  Text(0, 0, 'PLAZA 1RO DE MAYO'),
#  Text(0, 0, 'PLAZA A DEL VALLE'),
#  Text(0, 0, 'PLAZA ALEM'),
#  Text(0, 0, 'PLAZA ALMAGRO'),
#  Text(0, 0, 'PLAZA ARENALES'),
#  Text(0, 0, 'PLAZA BALCARCE'),
#  Text(0, 0, 'PLAZA BOEDO'),
#  Text(0, 0, 'PLAZA CASTELLI (COMUNA 13)'),
#  Text(0, 0, 'PLAZA COLOMBIA'),
#  Text(0, 0, 'PLAZA DON BOSCO'),
#  Text(0, 0, 'PLAZA GUEMES'),
#  Text(0, 0, 'PLAZA M BELGRANO'),
#  Text(0, 0, 'PLAZA M DE ANDREA'),
#  Text(0, 0, 'PLAZA PALERMO VIEJO'),
#  Text(0, 0, 'PLAZA PUEYRREDON'),
#  Text(0, 0, 'PLAZA SANTOJANNI'),
#  Text(0, 0, 'PLAZA SUDAMERICANA'),
#  Text(0, 0, 'PLAZA VELEZ SARSFIELD'),
#  Text(0, 0, 'PLAZA VERA PENIALOZA'),
#  Text(0, 0, 'PLAZOLETA REINO DE TAILANDIA'),
#  Text(0, 0, 'PUERTO MADERO')]

# %%
reciclaje.describe().iloc[:,3:10]
# Out:
#             VIDRIO  PAPEL_Y_CARTON        METAL     TELGOPOR  \
# count  2521.000000     2521.000000  2521.000000  2521.000000
# mean    241.801023      327.833270    21.668569     3.670588
# std     178.868752      232.606265    40.033340    13.501451
# min       0.000000        9.850000     0.000000     0.000000
# 25%     113.971000      170.120000     8.880000     0.000000
# 50%     208.610000      285.213000    18.300000     1.830000
# 75%     324.017000      425.418000    28.889000     3.960000
# max    1168.740000     1649.610000  1665.170000   338.910000
#
#        PLASTICOS_TODOS_LOS_DEMAS  TETRA_BRICK        TOTAL
# count                2521.000000  2521.000000  2521.000000
# mean                  139.681113     9.778578   744.433142
# std                    91.770326    12.315871   504.438929
# min                     0.000000     0.000000    24.690000
# 25%                    68.220000     3.682000   384.980000
# 50%                   126.969000     7.999000   660.334000
# ...
